# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp(C)  \
# 0        0                         weno   7.4515  151.8468        30.97
# 1        1                   isafjordur  66.0755  -23.1240         0.89
# 2        2  edinburgh of the seven seas -37.0676  -12.3116        14.59
# 3        3                    ariquemes  -9.9133  -63.0408        24.62
# 4        4                  olonkinbyen  70.9221   -8.7187         0.20
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        70         100        4.63      FM  1701663472
# 1        85         100        3.96      IS  1701663472
# 2        85           2        5.22      SH  1701663472
# 3        84          32        0.88      BR  1701663472
# 4        85          36        6.03      SJ  1701663472

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

map1 = city_data_df.hvplot.points(
    "Lng", "Lat", geo=True, tiles='EsriNatGeo', frame_width=700, frame_height=500,
    color="Humidity", size="Humidity", alpha=0.7,
    hover_cols=["City", "Country", "Humidity"]
)
# Display the map
# YOUR CODE HERE
map1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
ideal_conditions = (city_data_df["Max Temp(C)"] < 25) & (city_data_df["Max Temp(C)"] > 18) & (city_data_df['Wind Speed'] < 10) & (city_data_df['Cloudiness'] < 50)
ideal_cities_df = city_data_df[ideal_conditions]

# Drop any rows with null values
# YOUR CODE HERE
ideal_cities_df = ideal_cities_df.dropna()

# Display sample data
# YOUR CODE HERE
ideal_cities_df.sample(10)
# Out:
#      City_ID                City      Lat       Lng  Max Temp(C)  Humidity  \
# 408      408          brokopondo   4.7500  -55.1667        24.61        89
# 138      138        cidade velha  14.9167  -23.6167        24.26        78
# 102      102  riachao do jacuipe -11.8069  -39.3856        22.38        89
# 79        79        port lincoln -34.7333  135.8667        23.59        54
# 85        85            lilongwe -13.9669   33.7873        19.85        53
# 425      425             tsiombe -25.3000   45.4833        23.72        61
# 512      512        al majaridah  19.1236   41.9111        23.44        37
# 429      429          monkey bay -14.0728   34.9201        24.15        59
# 21        21           taoudenni  22.6783   -3.9836        21.96        39
# 571      571              berber  18.0216   33.9830        21.96        71
#
#      Cloudiness  Wind Speed Country        Date
# 408          23        3.76      SR  1701663537
# 138          20        7.20      CV  1701663496
# 102           2        1.82      BR  1701663294
# 79            9        7.05      AU  1701663484
# 85            1        0.80      MW  1701663486
# 425           1        6.79      MG  1701663540
# 512           0        3.33      SA  1701663555
# 429           0        5.85      MW  1701663540
# 21            0        3.69      ML  1701663475
# 571          20        3.38      SD  1701663565

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""

# Display sample data
# YOUR CODE HERE
hotel_df.sample(10)
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 570     saguenay      CA  48.4168  -71.0657        78
# 106        nadym      RU  65.5333   72.5167       100
# 98   kailua-kona      US  19.6406 -155.9956        84
# 320    draguseni      RO  45.9667   27.7500        69
# 58      cidreira      BR -30.1811  -50.2056        96
# 464      kalemie      CD  -5.9475   29.1947        95
# 345      ra-ngae      TH   6.2968  101.7284        76
# 370    pacasmayo      PE  -7.4006  -79.5714        85
# 39        avarua      CK -21.2078 -159.7750        61
# 430   valparaiso      CL -33.0393  -71.6273        66

# %%
geoapify_key
# Out:
# 'f5486bacd4344f868323b92719b97a6e'

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "type": hotel,
    "radius": radius,
    "limit": 1,
    "apiKey": geoapify_key,
    
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{radius}@{lng},{lat}"
    params["bias"] = f"circle:{radius}@{lng},{lat}"
  
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

     # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()
    
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.sample(10)

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}
# Print a message to follow up the hotel search
print("Starting hotel search")
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    # Convert the API response to JSON format
    name_address = name_address.json()
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
# Display sample data
hotel_df
# Out:
# Starting hotel search
# weno - nearest hotel: High Tide Hotel
# isafjordur - nearest hotel: Hótel Horn
# edinburgh of the seven seas - nearest hotel: No hotel found
# ariquemes - nearest hotel: Aquarius
# olonkinbyen - nearest hotel: No hotel found
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# atafu village - nearest hotel: No hotel found
# port mathurin - nearest hotel: Escale Vacances
# stanley - nearest hotel: Hotel 52
# serhetabat - nearest hotel: No hotel found
# port-aux-francais - nearest hotel: Keravel
# adamstown - nearest hotel: No hotel found
# hawaiian paradise park - nearest hotel: No hotel found
# lihue - nearest hotel: Kauai Palms
# bilibino - nearest hotel: No hotel found
# coquimbo - nearest hotel: Hotel Iberia
# gadzhiyevo - nearest hotel: Оазис
# blackmans bay - nearest hotel: Villa Howden
# tanumah - nearest hotel: No hotel found
# inhambane - nearest hotel: Hotel de Inhambane
# magadan - nearest hotel: Гостиница «ВМ-Центр»
# taoudenni - nearest hotel: No hotel found
# aasiaat - nearest hotel: SØMA
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# georgetown - nearest hotel: Page 63 hostel
# khovd - nearest hotel: Khovd hotel
# punta arenas - nearest hotel: Hotel Lacolet
# sawakin - nearest hotel: Hotel Halfa
# kodiak - nearest hotel: Shelikof Lodge
# bethel - nearest hotel: Hampton Inn Danbury
# barra de santo antonio - nearest hotel: Resort Fazenda Fiore
# pontian kechil - nearest hotel: Princess hotel
# puerto san jose - nearest hotel: Martita
# udachny - nearest hotel: Вилюй
# remire-montjoly - nearest hotel: Complexe Belova
# longyearbyen - nearest hotel: The Vault
# wanning - nearest hotel: No hotel found
# sisimiut - nearest hotel: Sømandshjemmet
# saint-philippe - nearest hotel: Le Baril
# avarua - nearest hotel: Paradise Inn
# papatowai - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# west island - nearest hotel: Cocos Village Bungalows
# hermanus - nearest hotel: Aloe guest house
# port elizabeth - nearest hotel: Waterford Hotel
# newman - nearest hotel: No hotel found
# nelson bay - nearest hotel: No hotel found
# palikir - national government center - nearest hotel: Mangrove Bay Hotel
# carnarvon - nearest hotel: No hotel found
# polyarnyy - nearest hotel: No hotel found
# hassi messaoud - nearest hotel: AMC
# tazovsky - nearest hotel: Тазовчанка
# grytviken - nearest hotel: No hotel found
# novyy urgal - nearest hotel: No hotel found
# waitangi - nearest hotel: Hotel Chathams
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# port alfred - nearest hotel: No hotel found
# klyuchi - nearest hotel: No hotel found
# cidreira - nearest hotel: Hotel Castelo
# bibir hat - nearest hotel: Hotel Green Residencial হোটেল গ্রিন আবাসিক একাডেমিতে
# pisco - nearest hotel: La Portada
# papao - nearest hotel: Hiti Moana Villa Lodge
# ra-ngae - nearest hotel: โรงแรมล่วนเฮง
# yacimiento rio turbio - nearest hotel: Capipe
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# callao - nearest hotel: Casa Ronald
# bandon - nearest hotel: The Munster Arms Hotel
# kozan - nearest hotel: No hotel found
# enewetak - nearest hotel: No hotel found
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# ribeira brava - nearest hotel: Cheerfulway Bravamar Hotel
# shitanjing - nearest hotel: No hotel found
# holualoa - nearest hotel: Kona Hotel
# morant bay - nearest hotel: Morant Villas
# tanout - nearest hotel: No hotel found
# nema - nearest hotel: No hotel found
# bloemfontein - nearest hotel: Stadium Inn
# imbituba - nearest hotel: Silvestre Praia Hotel
# naigarhi - nearest hotel: No hotel found
# buka - nearest hotel: No hotel found
# cill airne - nearest hotel: The Parkavon Hotel
# cariati - nearest hotel: Nettuno
# mineiros - nearest hotel: Hotel Dallas
# la passe - nearest hotel: L'Estuaire
# el granada - nearest hotel: Beach House
# geraldton - nearest hotel: Ocean Centre Hotel
# sao caetano de odivelas - nearest hotel: No hotel found
# pacasmayo - nearest hotel: Playa Linda
# lethem - nearest hotel: Hotel Amazonas
# sinabang - nearest hotel: No hotel found
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# shixing - nearest hotel: No hotel found
# padangsidempuan - nearest hotel: Hotel Mega Permata
# cestos city - nearest hotel: No hotel found
# deschutes river woods - nearest hotel: WorldMark Bend - Seventh Mountain Resort
# minas de marcona - nearest hotel: No hotel found
# general villegas - nearest hotel: Rucalén
# slavgorod - nearest hotel: Теремок
# plouzane - nearest hotel: Les Voyageurs
# eastham - nearest hotel: Four Points by Sheraton
# cockburn town - nearest hotel: The Salt Raker Inn
# juegang - nearest hotel: No hotel found
# namibe - nearest hotel: Hotel Chik Chik Namibe
# paphos - nearest hotel: Mayfair Hotel
# paracatu - nearest hotel: Hotel Presidente
# bandarbeyla - nearest hotel: No hotel found
# ouesso - nearest hotel: Auberge Nianina
# ifanadiana - nearest hotel: Win
# puerto santa - nearest hotel: No hotel found
# masterton - nearest hotel: Copthorne Hotel Solway Park
# harstad - nearest hotel: Scandic Harstad
# lorengau - nearest hotel: Seeadler Bay Hotel
# badarpur - nearest hotel: Meera Lodge
# ocean city - nearest hotel: Watson's Regency Suites
# krotovka - nearest hotel: Гостиница спорткомплекса
# santo antonio - nearest hotel: Pousada Onça Puma
# lesosibirsk - nearest hotel: No hotel found
# kitimat - nearest hotel: MStar Hotel
# baise city - nearest hotel: 梦之源大酒店
# viedma - nearest hotel: Níjar
# tolanaro - nearest hotel: Hôtel Mahavokey
# puerto baquerizo moreno - nearest hotel: Dory's House
# egletons - nearest hotel: Hôtel Ibis
# alice springs - nearest hotel: Aurora Alice Springs
# saint-paul - nearest hotel: Hôtel d'application
# brokopondo - nearest hotel: Matu eiland
# mana - nearest hotel: Le Samana
# grants - nearest hotel: Southwest Motel
# zouerate - nearest hotel: فندق تيرس زمور
# palmeira das missoes - nearest hotel: Hotel de Carli
# ghansor - nearest hotel: No hotel found
# lawas - nearest hotel: World Trade Hotel Batangas
# shalkar - nearest hotel: Бекнур
# midvagur - nearest hotel: GiljaHome
# kem' - nearest hotel: Кемь
# llanes - nearest hotel: Los Molinos
# katabu - nearest hotel: No hotel found
# whitefish - nearest hotel: The Firebrand Hotel
# markovo - nearest hotel: No hotel found
# estevan - nearest hotel: Days Inn
# solnechnyy - nearest hotel: Заря
# ad dilam - nearest hotel: No hotel found
# rikaze - nearest hotel: Gesar Hotel
# lospalos - nearest hotel: Hotel Roberto Carlos
# konarka - nearest hotel: Hotel Sun Village
# nuuk - nearest hotel: Nordbo
# sao domingos do maranhao - nearest hotel: No hotel found
# brisas de zicatela - nearest hotel: Casa de Olas
# brookings - nearest hotel: Quality Inn
# latina - nearest hotel: 018_U341-002- Accomodation
# tremonton - nearest hotel: Hampton
# vengerovo - nearest hotel: No hotel found
# kambove - nearest hotel: No hotel found
# mandera - nearest hotel: Kornesh Hotel and Lodging
# adrar - nearest hotel: No hotel found
# coruripe - nearest hotel: No hotel found
# gejiu - nearest hotel: No hotel found
# chonchi - nearest hotel: Hotel Huildín
# boguchany - nearest hotel: Полет
# al majaridah - nearest hotel: No hotel found
# las heras - nearest hotel: Posadas del Sur
# zvezdnyy - nearest hotel: Мулянка
# north bay - nearest hotel: Days Inn
# mount isa - nearest hotel: Ibis Styles
# huangmei - nearest hotel: No hotel found
# robbah - nearest hotel: No hotel found
# mitu - nearest hotel: Hotel Brasilia Vaupés
# neustadt am rubenberge - nearest hotel: Stadtschänke Helfers
# monroeville - nearest hotel: DoubleTree by Hilton Hotel Pittsburgh - Monroeville Convention Center
# izazi - nearest hotel: No hotel found
# al bukayriyah - nearest hotel: Ramada Hotel & Suites Al Qassim
# ciudad melchor muzquiz - nearest hotel: No hotel found
# mar del plata - nearest hotel: Gran hotel Mónaco
# turpan - nearest hotel: Oriental
# gamba - nearest hotel: No hotel found
# mendi - nearest hotel: Kiburu Lodge
# balikpapan - nearest hotel: Hotel Grand Senyiur
# san jose de jachal - nearest hotel: San Martin
# kulhudhuffushi - nearest hotel: No hotel found
# jinchang - nearest hotel: No hotel found
# castillos - nearest hotel: A mi gente
# bel ombre - nearest hotel: Villa La Cachette
# gryazi - nearest hotel: Виктория
# terrace heights - nearest hotel: Oxford Suites Yakima
# beloyarskiy - nearest hotel: Сибирь
# howard springs - nearest hotel: No hotel found
# puerto carreno - nearest hotel: Carreño Plaza
# athens - nearest hotel: Eridanus
# peace river - nearest hotel: New Ridge Inn
# tutoia - nearest hotel: Pousada San Vicente

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_with_hotels = hotel_df.hvplot.points(
    "Lng", "Lat", geo=True, tiles='EsriNatGeo', frame_width=700, frame_height=500,
    color="Humidity", size="Humidity", alpha=0.7,
    hover_cols=["City", "Country", "Humidity", "Hotel Name"]
)

# Display the map
map_with_hotels
